# %%
# !pip install qiskit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 43.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 16.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.5/107.5 kB 12.7 MB/s eta 0:00:00
# ...

# %%
import lib
import matplotlib.pyplot as plt
import math
from qiskit.visualization import plot_histogram
from qiskit.quantum_info import Statevector
import numpy as np

def fn(x):
    return (1/(2*math.pi))*math.exp(-((x)**2) / 2)


def supremum_infimum(func, interval):
    a, b = interval  # Unpack start and end points

    # Sample points within the interval (adjust num_points as needed)
    num_points = 2**15
    samples = np.linspace(a, b, num_points)

    # Evaluate function at sample points
    function_values = [func(x) for x in samples]

    # Estimate supremum and infimum using NumPy
    sup = np.max(function_values)
    inf = np.min(function_values)
    # print(np.sum(function_values))
    return sup, inf

# Example usage (replace 'your_function' with your actual function)
def your_function(x):
    return x**2

def get_k0(eps, fn, interval):
    sup, inf = supremum_infimum(fn, interval)
    return max(math.ceil(math.log2(max(abs(sup),abs(inf))/eps)), 2)

def fidelity(psi1, psi2):
    overlap = np.abs(np.dot((np.array(psi1).conj()), np.array(psi2)))**2
    return overlap

def test_fn(x):
    return math.exp(math.sin(x))

def double_derivative_test_fn(x):
    return -test_fn(x)*(math.sin(x)-math.cos(x)**2)

# %%
qc = lib.get_naive_quantum_circuit(8, fn, -3.8, 3.8)
plt.plot(Statevector(qc).probabilities())
plt.show()

# %%
qc = lib.get_approximate_quantum_circuit(12, fn, -3.8, 3.8, 9)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 12')
plt.ylabel('Probability of each states')
plt.show()

# %%
qc = lib.get_approximate_quantum_circuit(14, fn, -3.8, 3.8, 9)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 14')
plt.ylabel('Probability of each states')
plt.show()

# %%
qc = lib.get_approximate_quantum_circuit(16, fn, -3.8, 3.8, 9)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 16')
plt.ylabel('Probability of each states')
plt.show()

# %%
qc = lib.get_approximate_quantum_circuit(18, fn, -3.8, 3.8, 9)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 18')
plt.ylabel('Probability of each states')
plt.show()

# %%
qc = lib.get_approximate_quantum_circuit(12, fn, -3.8, 3.8, 4)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 12')
plt.ylabel('Probability of each states')
plt.show()

# %%
qc = lib.get_approximate_quantum_circuit(14, fn, -3.8, 3.8, 4)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 14')
plt.ylabel('Probability of each states')
plt.show()

# %%
qc = lib.get_approximate_quantum_circuit(16, fn, -3.8, 3.8, 4)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 16')
plt.ylabel('Probability of each states')
plt.show()

# %%
qc = lib.get_approximate_quantum_circuit(18, fn, -3.8, 3.8, 4)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 18')
plt.ylabel('Probability of each states')
plt.show()

# %%
def sin_fn(x):
  return math.exp(math.sin(x))

# %%
qc = lib.get_approximate_quantum_circuit(9, sin_fn, 0, 2*np.pi, 9)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 9')
plt.ylabel('Probability of each states')
plt.show()

# %%
qc = lib.get_approximate_quantum_circuit(12, sin_fn, 0, 2*np.pi, 9)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 12')
plt.ylabel('Probability of each states')
plt.show()

# %%
qc = lib.get_approximate_quantum_circuit(14, sin_fn, 0, 2*np.pi, 9)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 14')
plt.ylabel('Probability of each states')
plt.show()

# %%
qc = lib.get_approximate_quantum_circuit(16, sin_fn, 0, 2*np.pi, 9)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 16')
plt.ylabel('Probability of each states')
plt.show()

# %%
qc = lib.get_approximate_quantum_circuit(18, sin_fn, 0, 2*np.pi, 9)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 18')
plt.ylabel('Probability of each states')
plt.show()

# %%
qc = lib.get_approximate_quantum_circuit(12, sin_fn, 0, 2*np.pi, 5)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 12')
plt.ylabel('Probability of each states')
plt.show()

# %%
qc = lib.get_approximate_quantum_circuit(14, sin_fn, 0, 2*np.pi, 5)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 14')
plt.ylabel('Probability of each states')
plt.show()

# %%
qc = lib.get_approximate_quantum_circuit(16, sin_fn, 0, 2*np.pi, 5)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 16')
plt.ylabel('Probability of each states')
plt.show()

# %%
qc = lib.get_approximate_quantum_circuit(18, sin_fn, 0, 2*np.pi, 5)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 18')
plt.ylabel('Probability of each states')
plt.show()

# %%
def ex_fn(x):
  return math.exp(-x)

# %%
qc = lib.get_approximate_quantum_circuit(9, ex_fn, 0, 1, 5)
plt.plot(Statevector(qc).probabilities())
plt.xlabel('Discretize in 2^N points, N = 9')
plt.ylabel('Probability of each states')
plt.show()

# %%
qc_grover = lib.get_naive_quantum_circuit(9, ex_fn, 0, 1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-56-031cab0eb846> in <cell line: 1>()
# ----> 1 qc_grover = lib.get_naive_quantum_circuit(9, ex_fn, 0, 1)
#
# /content/lib.py in get_naive_quantum_circuit(num_qubit, fn, x_min, x_max)
#      41             cbit = [bit for bit in range(k - 1)]
#      42             if k > 1:
# ---> 43                 cry = cry.control(k - 1)
#      44             if len(item) > 0 and k > 1:
#      45                 qc.x(item)
#
# /usr/local/lib/python3.10/dist-packages/qiskit/circuit/library/standard_gates/ry.py in control(self, num_ctrl_qubits, label, ctrl_state, annotated)
#      96             gate.base_gate.label = self.label
#      97         else:
# ---> 98             gate = super().control(
#      99                 num_ctrl_qubits=num_ctrl_qubits,
#     100                 label=label,
#
# ...

# %%
plt.plot(Statevector(qc_grover).probabilities())
plt.xlabel('Discretize in 2^N points, N = 9')
plt.ylabel('Probability of each states')
plt.show()

# %%
print(fidelity(Statevector(qc_grover), Statevector(qc)))
# Out:
# 0.9999797349152586

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generate data for the normal distribution
mu = 0  # mean
sigma = 1  # standard deviation
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, mu, sigma)

# Plot the normal distribution
plt.plot(x, y, 'k-', linewidth=2)

# Fill the area under the curve
plt.fill_between(x, y, color='blue', alpha=0.3)

# Set labels and title
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.title('Normal Distribution')

# Show the plot
plt.grid(True)
plt.show()
